# %% [markdown]
# <a href="https://colab.research.google.com/github/GUNWOOOH/ADP_Practice/blob/main/%EC%8B%A4%EC%8A%B5/ADP%EC%8B%A4%EC%8A%B5_4%EC%A3%BC%EC%B0%A8_%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Date Preparing
#
# data: self made dataset

# %%
# 딕셔너리 성적 리스트
grade_dic = {
    '국어': [98, 88, 68, 64, 120],
    '영어': [None, 90, 60, 20, 50],
    '수학': [90, 70, None, 31, None],
    '과학': [120, 50, None, 60, 88]
}

# %%
#1. 열 순서 변경
from pandas import DataFrame

# 데이터 프레임
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# 열 순서 변경
df_columns = df.reindex(columns=['국어', '수학', '영어', '과학'])

# 열 순서 변경 후 출력
df_columns.head()
# Out:
#        국어    수학    영어     과학
# 노진구    98  90.0   NaN  120.0
# 이슬이    88  70.0  90.0   50.0
# 비실이    68   NaN  60.0    NaN
# 퉁퉁이    64  31.0  20.0   60.0
# 도라에몽  120   NaN  50.0   88.0

# %%
#2. 행 순서 변경
# 데이터 프레임
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# 행 순서 변경
df_index = df.reindex(index=['이슬이', '노진구', '퉁퉁이', '비실이', '도라에몽'])

# 행 순서 변경 후 출력
df_index
# Out:
#        국어    영어    수학     과학
# 이슬이    88  90.0  70.0   50.0
# 노진구    98   NaN  90.0  120.0
# 퉁퉁이    64  20.0  31.0   60.0
# 비실이    68  60.0   NaN    NaN
# 도라에몽  120  50.0   NaN   88.0

# %%
#3. 행 열 이름 변경
# 데이터 프레임
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# 열, 행 이름 변경
df_c_i = df.rename(
    columns={
        '국어': 'kor', '영어': 'eng', '수학': 'math', '과학': 'sin'
    },
    index={
        '노진구': 'no', '이슬이': 'is', '비실이': 'bs', '퉁퉁이': 'tt', '도라에몽': 'dr'
    }
)

# 열, 행 이름 변경 후 출력
df_c_i
# Out:
#     kor   eng  math    sin
# no   98   NaN  90.0  120.0
# is   88  90.0  70.0   50.0
# bs   68  60.0   NaN    NaN
# tt   64  20.0  31.0   60.0
# dr  120  50.0   NaN   88.0

# %%
#4. 행 열 이름 변경 (replace)
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# 원본 수정
# inplace=True -> 원본 값 수정
df.rename(
    columns={
        '국어': 'kor', '영어': 'eng', '수학': 'math', '과학': 'sin'
    }, inplace=True
)

# 원본 수정 후 출력
df
# Out:
#       kor   eng  math    sin
# 노진구    98   NaN  90.0  120.0
# 이슬이    88  90.0  70.0   50.0
# 비실이    68  60.0   NaN    NaN
# 퉁퉁이    64  20.0  31.0   60.0
# 도라에몽  120  50.0   NaN   88.0

# %%
#5. 특정 열 정렬
# 데이터 프레임
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# 특정 열 오름차순
df.sort_values('국어', inplace=True)
df
# Out:
#        국어    영어    수학     과학
# 퉁퉁이    64  20.0  31.0   60.0
# 비실이    68  60.0   NaN    NaN
# 이슬이    88  90.0  70.0   50.0
# 노진구    98   NaN  90.0  120.0
# 도라에몽  120  50.0   NaN   88.0

# %%
#6. 특정 열 두개 정렬
# 데이터 프레임
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# 두 개 이상의 열로 정렬
# 국어 점수가 동일할 경우 과학점수 순으로 정렬
df.sort_values(['국어', '과학'], inplace=True)
df
# Out:
#        국어    영어    수학     과학
# 퉁퉁이    64  20.0  31.0   60.0
# 비실이    68  60.0   NaN    NaN
# 이슬이    88  90.0  70.0   50.0
# 노진구    98   NaN  90.0  120.0
# 도라에몽  120  50.0   NaN   88.0

# %%
#7. 특정 조건 행 조회
# 데이터 프레임
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# 특정 조건 행 조회
search_index = df.query('국어 > 70')

# 출력
search_index
# Out:
#        국어    영어    수학     과학
# 노진구    98   NaN  90.0  120.0
# 이슬이    88  90.0  70.0   50.0
# 도라에몽  120  50.0   NaN   88.0

# %%
#8. 다중조건 행 조회

df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# 다중 조건 행 조회
# and 조건
all_index = df.query('국어 > 70 and 과학 > 60')
all_index
# Out:
#        국어    영어    수학     과학
# 노진구    98   NaN  90.0  120.0
# 도라에몽  120  50.0   NaN   88.0

# %%
#9. 다중조건 행 or
# 데이터 프레임
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# 다중 조건 행 조회
# or 조건
all_index = df.query('국어 < 50 or 영어 < 40')
all_index
# Out:
#      국어    영어    수학    과학
# 퉁퉁이  64  20.0  31.0  60.0

# %%
#10. 리스트 행 추가
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 리스트 행 추가
df.loc['짱구'] = [90, 80, 70, 30]
df
# 누락되는 값(결측치) 또는 초과에 경우 에러 발생
#df.loc['짱구'] = [70, 20, 34, 10, 49]
# Out:
#        국어    영어    수학     과학
# 노진구    98   NaN  90.0  120.0
# 이슬이    88  90.0  70.0   50.0
# 비실이    68  60.0   NaN    NaN
# 퉁퉁이    64  20.0  31.0   60.0
# 도라에몽  120  50.0   NaN   88.0
# 짱구     90  80.0  70.0   30.0

# %%
#11. 행 복사

df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 행 복사
df.loc['짱구'] = df.loc['도라에몽']

df
# Out:
#          국어    영어    수학     과학
# 노진구    98.0   NaN  90.0  120.0
# 이슬이    88.0  90.0  70.0   50.0
# 비실이    68.0  60.0   NaN    NaN
# 퉁퉁이    64.0  20.0  31.0   60.0
# 도라에몽  120.0  50.0   NaN   88.0
# 짱구    120.0  50.0   NaN   88.0

# %%
# 11. 행 병합

df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 다른 데이터 프레임 병합
# 제외된 열 -> NaN(결측치)
# sort -> 열을 이름순으로 정렬(기본값 : true)

df2 = DataFrame({'국어': 34, '수학': 40, '과학': 90}, index=['짱구'])
#new_df = df.append(df2, sort=False) 이건 앞으로 버전에서는 사용 x
new_df = pd.concat([df, df2], axis = 0)
new_df
# Out:
#        국어    영어    수학     과학
# 노진구    98   NaN  90.0  120.0
# 이슬이    88  90.0  70.0   50.0
# 비실이    68  60.0   NaN    NaN
# 퉁퉁이    64  20.0  31.0   60.0
# 도라에몽  120  50.0   NaN   88.0
# 짱구     34   NaN  40.0   90.0

# %%
# 12. 한개 행 삭제
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 행 삭제(결과 반영된 복사본 생성)
del_df = df.drop('노진구')

del_df
# Out:
#        국어    영어    수학    과학
# 이슬이    88  90.0  70.0  50.0
# 비실이    68  60.0   NaN   NaN
# 퉁퉁이    64  20.0  31.0  60.0
# 도라에몽  120  50.0   NaN  88.0

# %%
# 13. 행 여러개 삭제
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 행 여러개 삭제
del_df = df.drop(['이슬이', '퉁퉁이', '도라에몽'])

del_df
# Out:
#      국어    영어    수학     과학
# 노진구  98   NaN  90.0  120.0
# 비실이  68  60.0   NaN    NaN

# %%
#14. 인덱스 사용해서 삭제
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 인덱싱을 이용 삭제
del_df = df.drop(df.index[0])

del_df
# Out:
#        국어    영어    수학    과학
# 이슬이    88  90.0  70.0  50.0
# 비실이    68  60.0   NaN   NaN
# 퉁퉁이    64  20.0  31.0  60.0
# 도라에몽  120  50.0   NaN  88.0

# %%
# 15. 슬라이싱 사용하여 삭제
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 슬라이싱 사용 삭제
del_df = df.drop(df.index[2:5])
del_df
# Out:
#      국어    영어    수학     과학
# 노진구  98   NaN  90.0  120.0
# 이슬이  88  90.0  70.0   50.0

# %%
# 16. 열 추가

df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 새로운 열 추가
df['프로그래밍'] = [92, 49, 21, 20, None]
df
# Out:
#        국어    영어    수학     과학  프로그래밍
# 노진구    98   NaN  90.0  120.0   92.0
# 이슬이    88  90.0  70.0   50.0   49.0
# 비실이    68  60.0   NaN    NaN   21.0
# 퉁퉁이    64  20.0  31.0   60.0   20.0
# 도라에몽  120  50.0   NaN   88.0    NaN

# %%
# 17. 같은 값으로 열 추가

df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 새로운 열 같은값으로 추가
df['프로그래밍'] = 100
df
# Out:
#        국어    영어    수학     과학  프로그래밍
# 노진구    98   NaN  90.0  120.0    100
# 이슬이    88  90.0  70.0   50.0    100
# 비실이    68  60.0   NaN    NaN    100
# 퉁퉁이    64  20.0  31.0   60.0    100
# 도라에몽  120  50.0   NaN   88.0    100

# %%
# 18. 열 삭제
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 열 삭제하기
column_del = df.drop('영어', axis=1)
column_del
# Out:
#        국어    수학     과학
# 노진구    98  90.0  120.0
# 이슬이    88  70.0   50.0
# 비실이    68   NaN    NaN
# 퉁퉁이    64  31.0   60.0
# 도라에몽  120   NaN   88.0

# %%
# 19. 여러개 열 삭제

df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 열 여러개 삭제하기
column_del = df.drop(['영어', '과학'], axis=1)
column_del
# Out:
#        국어    수학
# 노진구    98  90.0
# 이슬이    88  70.0
# 비실이    68   NaN
# 퉁퉁이    64  31.0
# 도라에몽  120   NaN

# %%
# 19. 특정 열로 데이터프레임 생성
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])
df['프로그래밍'] = [92, 49, 21, 20, None]

# print_df(df)

# 특정 열만 필터링하여 새로운 데이터 프레임 생성
df2 = df.filter(items=['영어', '프로그래밍'])
df2
# Out:
#         영어  프로그래밍
# 노진구    NaN   92.0
# 이슬이   90.0   49.0
# 비실이   60.0   21.0
# 퉁퉁이   20.0   20.0
# 도라에몽  50.0    NaN

# %%
# 20. 결측치 확인

df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 결측치 확인
null_data = df.isnull()
null_data2 = df.isna()

null_data2
# Out:
#          국어     영어     수학     과학
# 노진구   False   True  False  False
# 이슬이   False  False  False  False
# 비실이   False  False   True   True
# 퉁퉁이   False  False  False  False
# 도라에몽  False  False   True  False

# %%
# 21. 결측치 수 파악
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

null_data = df.isnull()

# 결측치 수 파악
null_data_sum = null_data.sum()
null_data_sum
# Out:
# 국어    0
# 영어    1
# 수학    2
# 과학    1
# dtype: int64

# %%
# 21. 결측치 행 삭제
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 결측치 모든 행 삭제
null_data_del = df.dropna()

null_data_del.isnull().sum()
# Out:
# 국어    0
# 영어    0
# 수학    0
# 과학    0
# dtype: int64

# %%
# 22. 결측치 포함 열 삭제

df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 결측치 모든 열 삭제
null_data_del = df.dropna(axis=1)
null_data_del

#null_data_del.isnull().sum()
# Out:
# 국어    0
# dtype: int64

# %%
# 23. 행의 모든 값이 결측치일 때 삭제

df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 행의 모든 값이 결측치 일시 행을 삭제
null_data_del = df.dropna(how='all')
null_data_del
# Out:
#        국어    영어    수학     과학
# 노진구    98   NaN  90.0  120.0
# 이슬이    88  90.0  70.0   50.0
# 비실이    68  60.0   NaN    NaN
# 퉁퉁이    64  20.0  31.0   60.0
# 도라에몽  120  50.0   NaN   88.0

# %%
# 24. 열이 모두 결측치일 때 삭제
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 열의 모든 값이 결측치 일시 열을 삭제
null_data_del = df.dropna(how='all', axis=1)
null_data_del
# Out:
#        국어    영어    수학     과학
# 노진구    98   NaN  90.0  120.0
# 이슬이    88  90.0  70.0   50.0
# 비실이    68  60.0   NaN    NaN
# 퉁퉁이    64  20.0  31.0   60.0
# 도라에몽  120  50.0   NaN   88.0

# %%
# 24. 대표값으로 대체

df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 결측치 대표값으로 대체
re_null_data = df.fillna(value=0)
re_null_data
# Out:
#        국어    영어    수학     과학
# 노진구    98   0.0  90.0  120.0
# 이슬이    88  90.0  70.0   50.0
# 비실이    68  60.0   0.0    0.0
# 퉁퉁이    64  20.0  31.0   60.0
# 도라에몽  120  50.0   0.0   88.0

# %%
from sklearn.impute import SimpleImputer
import numpy
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])

# print_df(df)

# 결측치 규칙 정의
null_regulation = SimpleImputer(
    missing_values=numpy.nan, strategy='most_frequent')

# 결측치 규칙 적용
df_null_regulation = null_regulation.fit_transform(df.values)
df_null_regulation

# 결측치 규칙 적용 데이터 프레임 생성
df2 = DataFrame(df_null_regulation, index=df.index, columns=df.columns)

df2
# Out:
#          국어    영어    수학     과학
# 노진구    98.0  20.0  90.0  120.0
# 이슬이    88.0  90.0  70.0   50.0
# 비실이    68.0  60.0  31.0   50.0
# 퉁퉁이    64.0  20.0  31.0   60.0
# 도라에몽  120.0  50.0  31.0   88.0

# %%
# 25. 이상치 탐색
def outlier_iqr(data, column): 

    # lower, upper 글로벌 변수 선언하기     
    global lower, upper    
    
    # 4분위수 기준 지정하기     
    q25, q75 = np.quantile(data[column], 0.25), np.quantile(data[column], 0.75)          
    
    # IQR 계산하기     
    iqr = q75 - q25    
    
    # outlier cutoff 계산하기     
    cut_off = iqr * 1.5          
    
    # lower와 upper bound 값 구하기     
    lower, upper = q25 - cut_off, q75 + cut_off     
    
    print('IQR은',iqr, '이다.')     
    print('lower bound 값은', lower, '이다.')     
    print('upper bound 값은', upper, '이다.')    
    
    # 1사 분위와 4사 분위에 속해있는 데이터 각각 저장하기     
    data1 = data[data[column] > upper]     
    data2 = data[data[column] < lower]    
    
    # 이상치 총 개수 구하기
    return print('총 이상치 개수는', data1.shape[0] + data2.shape[0], '이다.')

# %%
df = DataFrame(grade_dic, index=['노진구', '이슬이', '비실이', '퉁퉁이', '도라에몽'])
df
# Out:
#        국어    영어    수학     과학
# 노진구    98   NaN  90.0  120.0
# 이슬이    88  90.0  70.0   50.0
# 비실이    68  60.0   NaN    NaN
# 퉁퉁이    64  20.0  31.0   60.0
# 도라에몽  120  50.0   NaN   88.0

# %%
outlier_iqr(df,'국어')
# Out:
# IQR은 30.0 이다.
# lower bound 값은 23.0 이다.
# upper bound 값은 143.0 이다.
# 총 이상치 개수는 0 이다.

# %%
data = df[(df['국어'] < upper) & (df['국어'] > lower)]

len(data)
# Out:
# 5

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.distplot(df.국어, kde=False)


# 이상치 영역 박스 그리기

plt.axvspan(xmin=lower, xmax=df.국어.min(), alpha=0.2, color='red')

plt.axvspan(xmin=upper, xmax=df.국어.max(), alpha=0.2, color='red')
# Out:
# <ipython-input-114-5c821323e104>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.국어, kde=False)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...
